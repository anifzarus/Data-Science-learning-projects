# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    preg  plasma  pressure  skin  insulin  mass  pediatric  age     class
# 0     6     148        72    35        0  33.6      0.627   50  positive
# 1     1      85        66    29        0  26.6      0.351   31  negative
# 2     8     183        64     0        0  23.3      0.672   32  positive
# 3     1      89        66    23       94  28.1      0.167   21  negative
# 4     0     137        40    35      168  43.1      2.288   33  positive

# %%
df.describe()
# Out:
#              preg      plasma    pressure        skin     insulin        mass  \
# count  739.000000  739.000000  739.000000  739.000000  739.000000  739.000000
# mean     3.818674  120.635995   68.897158   20.457375   80.408660   31.892558
# std      3.341393   32.024446   19.556540   15.917785  115.573687    7.914320
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.200000
# 50%      3.000000  117.000000   72.000000   23.000000   36.000000   32.000000
# 75%      6.000000  140.000000   80.000000   32.000000  129.500000   36.500000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#         pediatric         age
# count  739.000000  739.000000
# mean     0.472294   33.101488
# std      0.332040   11.729759
# min      0.078000   21.000000
# 25%      0.243500   24.000000
# 50%      0.375000   29.000000
# 75%      0.626500   40.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 9 columns):
# preg         739 non-null int64
# plasma       739 non-null int64
# pressure     739 non-null int64
# skin         739 non-null int64
# insulin      739 non-null int64
# mass         739 non-null float64
# pediatric    739 non-null float64
# age          739 non-null int64
# class        739 non-null object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 52.0+ KB

# %%
sns.set_style('whitegrid')
sns.countplot(x='class',data=df,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.distplot(df['age'],kde=False)

# %%
sns.pairplot(df,hue='class',palette='coolwarm')

# %%
sns.set_style('whitegrid')
plt.rcParams["figure.figsize"] = (20,6)
sns.countplot(x='age',hue='class',data=df,palette='RdBu_r')

# %%
df.groupby('class')
by_comp = df.groupby("class")

# %%
by_comp.describe()
# Out:
#            preg                                               plasma  \
#           count      mean       std  min  25%  50%  75%   max  count
# class
# negative  485.0  3.253608  2.962509  0.0  1.0  2.0  5.0  13.0  485.0
# positive  254.0  4.897638  3.741308  0.0  2.0  4.0  8.0  17.0  254.0
#
#                       ... pediatric           age                              \
#                 mean  ...       75%    max  count       mean        std   min
# class                 ...
# negative  110.018557  ...   0.56400  2.329  485.0  31.162887  11.696589  21.0
# positive  140.909449  ...   0.72575  2.420  254.0  36.803150  10.892968  21.0
#
#
#            25%   50%    75%   max
# class
# negative  23.0  27.0  37.00  81.0
# positive  28.0  35.0  43.75  70.0
#
# [2 rows x 64 columns]

# %%
by_comp.describe().transpose()
# Out:
# class              negative    positive
# preg      count  485.000000  254.000000
#           mean     3.253608    4.897638
#           std      2.962509    3.741308
#           min      0.000000    0.000000
#           25%      1.000000    2.000000
#           50%      2.000000    4.000000
#           75%      5.000000    8.000000
#           max     13.000000   17.000000
# plasma    count  485.000000  254.000000
#           mean   110.018557  140.909449
#           std     26.336696   32.185414
#           min      0.000000    0.000000
#           25%     93.000000  118.000000
#           50%    107.000000  139.500000
#           75%    125.000000  166.750000
#           max    197.000000  199.000000
# pressure  count  485.000000  254.000000
#           mean    68.103093   70.413386
#           std     18.212862   21.852686
#           min      0.000000    0.000000
#           25%     62.000000   66.000000
#           50%     70.000000   74.000000
# ...

# %%
df
# Out:
#      preg  plasma  pressure  skin  insulin  mass  pediatric  age     class
# 0       6     148        72    35        0  33.6      0.627   50  positive
# 1       1      85        66    29        0  26.6      0.351   31  negative
# 2       8     183        64     0        0  23.3      0.672   32  positive
# 3       1      89        66    23       94  28.1      0.167   21  negative
# 4       0     137        40    35      168  43.1      2.288   33  positive
# 5       5     116        74     0        0  25.6      0.201   30  negative
# 6       3      78        50    32       88  31.0      0.248   26  positive
# 7      10     115         0     0        0  35.3      0.134   29  negative
# 8       2     197        70    45      543  30.5      0.158   53  positive
# 9       8     125        96     0        0   0.0      0.232   54  positive
# 10      4     110        92     0        0  37.6      0.191   30  negative
# ...

# %%
mapping = {'positive': 1, 'negative': 2}

df.replace({'class': mapping},inplace=True)

# %%
df
# Out:
#      preg  plasma  pressure  skin  insulin  mass  pediatric  age  class
# 0       6     148        72    35        0  33.6      0.627   50      1
# 1       1      85        66    29        0  26.6      0.351   31      2
# 2       8     183        64     0        0  23.3      0.672   32      1
# 3       1      89        66    23       94  28.1      0.167   21      2
# 4       0     137        40    35      168  43.1      2.288   33      1
# 5       5     116        74     0        0  25.6      0.201   30      2
# 6       3      78        50    32       88  31.0      0.248   26      1
# 7      10     115         0     0        0  35.3      0.134   29      2
# 8       2     197        70    45      543  30.5      0.158   53      1
# 9       8     125        96     0        0   0.0      0.232   54      1
# 10      4     110        92     0        0  37.6      0.191   30      2
# 11     10     168        74     0        0  38.0      0.537   34      1
# ...

# %%
df
# Out:
#      preg  plasma  pressure  skin  insulin  mass  pediatric  age  class
# 0       6     148        72    35        0  33.6      0.627   50      1
# 1       1      85        66    29        0  26.6      0.351   31      2
# 2       8     183        64     0        0  23.3      0.672   32      1
# 3       1      89        66    23       94  28.1      0.167   21      2
# 4       0     137        40    35      168  43.1      2.288   33      1
# 5       5     116        74     0        0  25.6      0.201   30      2
# 6       3      78        50    32       88  31.0      0.248   26      1
# 7      10     115         0     0        0  35.3      0.134   29      2
# 8       2     197        70    45      543  30.5      0.158   53      1
# 9       8     125        96     0        0   0.0      0.232   54      1
# 10      4     110        92     0        0  37.6      0.191   30      2
# 11     10     168        74     0        0  38.0      0.537   34      1
# ...

# %%
sns.distplot(df['insulin'],kde=False,bins=25)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('insulin',axis=1), 
                                                    df['class'], test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        73
#            2       1.00      1.00      1.00       149
#
#    micro avg       1.00      1.00      1.00       222
#    macro avg       1.00      1.00      1.00       222
# weighted avg       1.00      1.00      1.00       222

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 73   0]
#  [  0 149]]
